# %%
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import glob
import random

# %% [markdown]
# 이미지를 28 * 28 크기로 바꾸는 함수

# %%
def resize_images(img_path):
    images = glob.glob(img_path + "/*.jpg")

    # 파일마다 모두 28x28 사이즈로 바꾸어 저장합니다.
    target_size = (28, 28)
    for img in images:
        old_img = Image.open(img)
        new_img = old_img.resize(target_size, Image.ANTIALIAS)
        new_img.save(img, "JPEG")

    print(f"{len(images)} 개의 이미지 크기변경")

# %% [markdown]
# 학습 이미지들의 크기변경.
# 총 학습 이미지는 949개이다.

# %%
resize_images("C:/Users/kwansu/Desktop/AIFFEL_LMS/E_01_RockPaperScissor/data/scissor")
resize_images("C:/Users/kwansu/Desktop/AIFFEL_LMS/E_01_RockPaperScissor/data/rock")
resize_images("C:/Users/kwansu/Desktop/AIFFEL_LMS/E_01_RockPaperScissor/data/paper")
# Out:
# 258 개의 이미지 크기변경
# 356 개의 이미지 크기변경
# 335 개의 이미지 크기변경

# %%
Image.open("C:/Users/kwansu/Desktop/AIFFEL_LMS/E_01_RockPaperScissor/data/example1.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x262A53C3088>

# %% [markdown]
# 위 이미지 처럼 사람이 보기에도 부정확하거나, 학습에 오히려 방해가 될 데이터는 모두 제거하였다.
#
# 그리고 테스트 데이터도 같은 방법으로 크기를 변경한다.
# 테스트 데이터는 총 300개이다.

# %%
resize_images("C:/Users/kwansu/Desktop/AIFFEL_LMS/E_01_RockPaperScissor/data/test/scissor")
resize_images("C:/Users/kwansu/Desktop/AIFFEL_LMS/E_01_RockPaperScissor/data/test/rock")
resize_images("C:/Users/kwansu/Desktop/AIFFEL_LMS/E_01_RockPaperScissor/data/test/paper")
# Out:
# 100 개의 이미지 크기변경
# 100 개의 이미지 크기변경
# 100 개의 이미지 크기변경

# %% [markdown]
# 이미지를 로드해서 데이터로 만드는 함수
#
# 기존의 이미지 개수 만큼 데이터를 만들던 것은 이미지 다양성이 부족하다고 생각되어,
# 기존 이미지의 좌우반전(2) * 90회전(4) * 색반전(2) = 이미지 * 16의 학습 데이터를 생성한다.
#
# 테스트 용 데이터도 이 함수로 만드는데, 굳이 테스트 데이터에 여러 작용을 거칠 필요가 없는 것 같아서
# 테스트용의 경우는 is_test=False인자를 True로 줄 경우 기존 이미지 개수 만큼만 만들게 하였다.
#
# default 이미지 데이터의 최대 개수는 16000 이다. (총 이미지는 이미지수 * 16 이다.)
# number_of_data=16000 인자의 개수를 변경하여 최대 개수를 변경가능하다.
# 그리고 생성한 이미지 데이터의 개수만큼 반환하도록 return imgs[:idx]로 변경하였다.

# %%
def load_data(img_path, *, number_of_data=16000, is_test = False):  # 테스트일 경우 is_test=True
    #이미지 데이터와 라벨(가위 : 0, 바위 : 1, 보 : 2) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    imgs=np.zeros([number_of_data, 28, 28, 3], dtype=np.int32)
    labels=np.zeros(number_of_data, dtype=np.int32)
    idx=0

    def calc_image_data(label, folder_name):
        for file in glob.iglob(img_path+f'/{folder_name}/*.jpg'):
            nonlocal idx
            img = Image.open(file)
            for _ in range(4):      # 이미지를 90도씩 회전하며 생성
                img = img.transpose(Image.ROTATE_90)
                imgs[idx,:,:,:] = np.array(img, dtype=np.int32)
                labels[idx]=label
                idx=idx+1
            
            if is_test:     # 테스트 데이터인 경우 다른 변형 처리를 넘긴다.
                continue

            img = img.transpose(Image.FLIP_LEFT_RIGHT)  # 좌우반전
            for _ in range(4):      # 이미지를 90도씩 회전하며 생성
                img = img.transpose(Image.ROTATE_90)
                imgs[idx,:,:,:] = np.array(img, dtype=np.int32)
                labels[idx]=label
                idx=idx+1

            # 색 반전
            for x in range(1 , 28):
                for y in range(1, 28):
                    img.putpixel((x,y), int(255-img.getpixel((x,y))[0]))

            for _ in range(4):      # 이미지를 90도씩 회전하며 생성
                img = img.transpose(Image.ROTATE_90)
                imgs[idx,:,:,:] = np.array(img, dtype=np.int32)
                labels[idx]=label
                idx=idx+1

            img = img.transpose(Image.FLIP_LEFT_RIGHT)  # 좌우반전
            for _ in range(4):      # 이미지를 90도씩 회전하며 생성
                img = img.transpose(Image.ROTATE_90)
                imgs[idx,:,:,:] = np.array(img, dtype=np.int32)
                labels[idx]=label
                idx=idx+1

    calc_image_data(0, 'scissor') # 각 라벨로 데이터 생성
    calc_image_data(1, 'rock')
    calc_image_data(2, 'paper')
      
    print(f"로드된 데이터의 이미지 개수는 {idx} 입니다.")
    return imgs[:idx], labels[:idx]

# %% [markdown]
# 준비해둔 학습데이터와 테스터 데이터를 로드하고, 정규화한다.
# 테스터 데이터의 경우는 is_test=True로 주어 생성한다.
#
# 그리고 이전에 코드에서는 fit함수로 학습시킬 경우, 학습중간에
# 검증용 데이터의 accuracy를 확인하기 위해서 validation_split를 인자로 넣었다.
#
# 문제는 현재 load_data로 불러들인 데이터는 이미지의 가위, 바위, 보 순으로 읽어 들이는데,
# tensorflow의 validation_split은 전체데이터에서 끝에서 데이터를 나눈 효과를 가졌다.
# 즉, validation_split을 사용시 보의 데이터만 떨어져 나가는 문제가 있었다. 심하면 학습용 보가 사라졌다.
#
# 그런 문제를 해결하기 위해 학습용 데이터를 suffle로 섞어주었다.
# x와 y를 인덱스를 똑같이 섞어주기 위해 섞인 order리스트를 이용하였다.
#
#
# 마지막으로 로드된 각 입력데이를 정규화하기 위해 255로 나누었다.
# x_test는 잘못 판단한 이미지 출력을 위해 x_test_normalized에 저장하였다.

# %%
(x_train, y_train)=load_data("C:/Users/kwansu/Desktop/AIFFEL_LMS/E_01_RockPaperScissor/data")

order = list(range(len(y_train)))     # x와 y의 인덱스를 동일하게 섞기 위한 리스트
random.shuffle(order)

x_train = x_train[order]/255.0   # 입력은 0~1 사이의 값으로 정규화
y_train = y_train[order]         # 인덱스를 섞은 order로 주어 똑같이 섞이게 만든다.

(x_test, y_test)=load_data("C:/Users/kwansu/Desktop/AIFFEL_LMS/E_01_RockPaperScissor/data/test",is_test=True)
x_test_normalized = x_test/255.0   # 입력은 0~1 사이의 값으로 정규화
# Out:
# 로드된 데이터의 이미지 개수는 15184 입니다.
# 로드된 데이터의 이미지 개수는 1200 입니다.

# %% [markdown]
# 앙상블 효과를 주기위해 모델의 생성과 학습을 함수로 만들었다.
# 클래스로 만들까 생각했지만, 딱히 필요성이 없어서 함수 2개로 구성하였다.
#
# 아래 함수는 모델을 생성해서 반환하는 함수이다.
# 모델의 구성은 각 레이어 사이에 batch normalize를 추가 하였다.
#
# regularization효과가 있기 때문에 따로 dropout등을 하지 않아도 되고, Internal Covariate Shift문제를 해결하여 안정적인 학습이 가능하게 도와준다.
#
# 또한 하나의 컴볼루션 레이어를 추가하고, learning_rate를 입력받게 변경하였다.

# %%
def create_model(channels_1, channels_2, dense_output, learning_rate):
    model=tf.keras.models.Sequential()
    model.add(tf.keras.layers.Conv2D(channels_1, (3,3), activation='relu', input_shape=(28,28,3)))
    
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(channels_2, (3,3), activation='relu'))
    model.add(tf.keras.layers.MaxPool2D(2,2))
    
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(channels_2, (3,3), activation='relu'))
    
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(channels_1, (3,3), activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D((2,2)))
    
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(dense_output, activation='relu'))
    
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dense(3, activation='softmax'))
    
    # learning_rate를 입력으로 받도록 변경하였다.
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# 함수를 통해 생성된 모델의 구성

# %%
dummy_model = create_model(64,128,128, 0.001)
dummy_model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_100 (Conv2D)          (None, 26, 26, 64)        1792
# _________________________________________________________________
# batch_normalization_125 (Bat (None, 26, 26, 64)        256
# _________________________________________________________________
# conv2d_101 (Conv2D)          (None, 24, 24, 128)       73856
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_126 (Bat (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_102 (Conv2D)          (None, 10, 10, 128)       147584
# _________________________________________________________________
# batch_normalization_127 (Bat (None, 10, 10, 128)       512
# _________________________________________________________________
# conv2d_103 (Conv2D)          (None, 8, 8, 64)          73792
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# batch_normalization_128 (Bat (None, 4, 4, 64)          256
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_50 (Dense)             (None, 128)               131200
# _________________________________________________________________
# batch_normalization_129 (Bat (None, 128)               512
# _________________________________________________________________
# dense_51 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 430,659
# Trainable params: 429,635
# Non-trainable params: 1,024
# _________________________________________________________________

# %% [markdown]
# 기존의 fit부분을 함수로 만들었다.
#
# validation_data로 test데이터를 넣어서 학습 도중의 결과를 나타내었다.
# 그리고 loss와 accurary를 그래프로 나타내었다.

# %%
import os

def save_model(model, path, filename, plt):
    file_path = f'{path}/{filename}'
    uniq = 1
    while os.path.exists(file_path + '.h5'):
        file_path = f'{path}/{filename}({uniq})'
        uniq += 1
        
    model.save(file_path + '.h5')
    plt.savefig(file_path + '.png')  # 나중에 확인가능하게 학습 그래프를 이미지로 같은 이름으로 저장한다.
    print(f"모델을 저장하였습니다. {file_path}'.h5'")

# %%
def train(model : tf.keras.Model, x_train, y_train, x_test, y_test, epochs):
    # fit과정 중의 기록인 history를 결과로 받는다.
    hist = model.fit(x_train, y_train, epochs=epochs, validation_data=(x_test,y_test))
    
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
    print(f"test_loss: {test_loss} ")
    print(f"test_accuracy: {test_accuracy}")
    
    # 기록들을 그래프로 나타낸다.
    fig = plt.figure()
    loss_ax = fig.add_subplot(2, 1, 1)
    acc_ax = fig.add_subplot(2, 1, 2)
    loss_ax.plot(hist.history['loss'], 'y', label='train loss')
    loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
    acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
    acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')
    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')
    acc_ax.set_ylabel('accuray')
    loss_ax.legend(loc='upper left')
    acc_ax.legend(loc='lower left')
    
    save_path = 'C:/Users/kwansu/Desktop/AIFFEL_LMS'
    filename = f'E01_{test_accuracy:f}_{test_loss:f}' # 정확도와 오차를 이름으로 한다
    save_model(model, save_path, filename, plt)   # 학습시킨 모델을 저장한다.
    
    plt.show()

# %% [markdown]
# 기존의 코드에서 하이퍼 파라미터로 learning_rate와 ensembles를 추가하였다.
#
# ensembles의 수만큼 모델을 생성하고 학습시킨다.
# 학습시간이 너무 길어지지 않게 적당히 4개의 모델만 만들었다.
#
#
# learing_rate의 경우 여러가지 실험결과 0.001일 경우 부터 테스트 데이터의 정답률이 0.99이상으로 갔다.
# 다만 0.001이 경우 테스트 데이터의 변동률이 커서 0.0001로 실험을 진행하자 적은 변동 폭으로
# 천천히 오르기는 하는데 150번의 epoch에서도 0.97정도로 학습이 너무 느렸다.
# 결과적으로 0.0005에서 100번에서 안정되는 학습률과 속도를 보였다.

# %%
n_train_epoch = 100
n_channel_1 = 64
n_channel_2 = 128
n_dense = 128
learning_rate = 0.0005
ensembles = 4

# 앙상블을 할 수만큼 모델들을 생성한다.
models = [create_model(n_channel_1, n_channel_2, n_dense,
                       learning_rate) for _ in range(ensembles)]
                       
for model in models:  # 각 모델들을 학습 시킨다.
    train(model, x_train, y_train, x_test_normalized, y_test, n_train_epoch)
# Out:
# Train on 15184 samples, validate on 1200 samples
# Epoch 1/100
# 15184/15184 [==============================] - 4s 246us/sample - loss: 0.2621 - accuracy: 0.8994 - val_loss: 0.6156 - val_accuracy: 0.7808
# Epoch 2/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0610 - accuracy: 0.9795 - val_loss: 0.3219 - val_accuracy: 0.8867
# Epoch 3/100
# 15184/15184 [==============================] - 3s 171us/sample - loss: 0.0403 - accuracy: 0.9866 - val_loss: 0.3149 - val_accuracy: 0.8908
# Epoch 4/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0202 - accuracy: 0.9939 - val_loss: 0.4409 - val_accuracy: 0.8825
# Epoch 5/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0285 - accuracy: 0.9911 - val_loss: 0.3256 - val_accuracy: 0.8783
# Epoch 6/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0214 - accuracy: 0.9932 - val_loss: 0.3167 - val_accuracy: 0.8875
# Epoch 7/100
# 15184/15184 [==============================] - 3s 171us/sample - loss: 0.0172 - accuracy: 0.9949 - val_loss: 0.2817 - val_accuracy: 0.9167
# Epoch 8/100
# 15184/15184 [==============================] - 3s 170us/sample - loss: 0.0088 - accuracy: 0.9975 - val_loss: 0.5383 - val_accuracy: 0.8725
# Epoch 9/100
# 15184/15184 [==============================] - 3s 170us/sample - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.1972 - val_accuracy: 0.9442
# Epoch 10/100
# 15184/15184 [==============================] - 3s 171us/sample - loss: 0.0242 - accuracy: 0.9924 - val_loss: 0.1248 - val_accuracy: 0.9500
# Epoch 11/100
# 15184/15184 [==============================] - 3s 169us/sample - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.2140 - val_accuracy: 0.9408
# Epoch 12/100
# 15184/15184 [==============================] - 3s 172us/sample - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.2475 - val_accuracy: 0.9208
# Epoch 13/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.3459 - val_accuracy: 0.9150
# Epoch 14/100
# 15184/15184 [==============================] - 3s 170us/sample - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.2688 - val_accuracy: 0.9242
# Epoch 15/100
# 15184/15184 [==============================] - 3s 172us/sample - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.1863 - val_accuracy: 0.9417
# Epoch 16/100
# 15184/15184 [==============================] - 3s 172us/sample - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0886 - val_accuracy: 0.9650
# Epoch 17/100
# 15184/15184 [==============================] - 3s 173us/sample - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.2104 - val_accuracy: 0.9375
# Epoch 18/100
# 15184/15184 [==============================] - 3s 172us/sample - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.1854 - val_accuracy: 0.9467
# Epoch 19/100
# 15184/15184 [==============================] - 3s 171us/sample - loss: 0.0150 - accuracy: 0.9954 - val_loss: 0.2455 - val_accuracy: 0.9300
# Epoch 20/100
# 15184/15184 [==============================] - 3s 172us/sample - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0520 - val_accuracy: 0.9775
# Epoch 21/100
# 15184/15184 [==============================] - 3s 169us/sample - loss: 9.8182e-04 - accuracy: 0.9997 - val_loss: 0.1292 - val_accuracy: 0.9567
# Epoch 22/100
# 15184/15184 [==============================] - 3s 169us/sample - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0795 - val_accuracy: 0.9733
# Epoch 23/100
# 15184/15184 [==============================] - 3s 170us/sample - loss: 3.5572e-04 - accuracy: 0.9999 - val_loss: 0.0464 - val_accuracy: 0.9875
# Epoch 24/100
# 15184/15184 [==============================] - 3s 173us/sample - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.1691 - val_accuracy: 0.9500
# Epoch 25/100
# 15184/15184 [==============================] - 3s 173us/sample - loss: 0.0073 - accuracy: 0.9978 - val_loss: 1.1681 - val_accuracy: 0.7550
# Epoch 26/100
# 15184/15184 [==============================] - 3s 171us/sample - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.1025 - val_accuracy: 0.9725
# Epoch 27/100
# 15184/15184 [==============================] - 3s 172us/sample - loss: 0.0035 - accuracy: 0.9991 - val_loss: 1.3351 - val_accuracy: 0.8158
# Epoch 28/100
# 15184/15184 [==============================] - 3s 171us/sample - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.1712 - val_accuracy: 0.9583
# Epoch 29/100
# 15184/15184 [==============================] - 3s 170us/sample - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.2736 - val_accuracy: 0.9158
# Epoch 30/100
# 15184/15184 [==============================] - 3s 171us/sample - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.1488 - val_accuracy: 0.9650
# Epoch 31/100
# 15184/15184 [==============================] - 3s 173us/sample - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1145 - val_accuracy: 0.9758
# Epoch 32/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1658 - val_accuracy: 0.9425
# Epoch 33/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1168 - val_accuracy: 0.9625
# Epoch 34/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.1256 - val_accuracy: 0.9617
# Epoch 35/100
# 15184/15184 [==============================] - 3s 172us/sample - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0604 - val_accuracy: 0.9792
# Epoch 36/100
# 15184/15184 [==============================] - 3s 170us/sample - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.3594 - val_accuracy: 0.9342
# Epoch 37/100
# 15184/15184 [==============================] - 3s 169us/sample - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.1005 - val_accuracy: 0.9708
# Epoch 38/100
# 15184/15184 [==============================] - 3s 170us/sample - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.1465 - val_accuracy: 0.9642
# Epoch 39/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 3.8995e-04 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9717
# Epoch 40/100
# 15184/15184 [==============================] - 3s 172us/sample - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0350 - val_accuracy: 0.9858
# Epoch 41/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.1929 - val_accuracy: 0.9517
# Epoch 42/100
# 15184/15184 [==============================] - 3s 171us/sample - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0570 - val_accuracy: 0.9842
# Epoch 43/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.1247 - val_accuracy: 0.9667
# Epoch 44/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 4.5952e-04 - accuracy: 0.9999 - val_loss: 0.1760 - val_accuracy: 0.9542
# Epoch 45/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.1564 - val_accuracy: 0.9567
# Epoch 46/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0879 - val_accuracy: 0.9767
# Epoch 47/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 9.0210e-04 - accuracy: 0.9998 - val_loss: 0.0943 - val_accuracy: 0.9783
# Epoch 48/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 1.8230e-04 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 0.9783
# Epoch 49/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.8314 - val_accuracy: 0.8925
# Epoch 50/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.1820 - val_accuracy: 0.9408
# Epoch 51/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 4.9382e-04 - accuracy: 0.9999 - val_loss: 0.1286 - val_accuracy: 0.9583
# Epoch 52/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 2.0356e-04 - accuracy: 0.9999 - val_loss: 0.0907 - val_accuracy: 0.9658
# Epoch 53/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 6.3669e-04 - accuracy: 0.9999 - val_loss: 0.0544 - val_accuracy: 0.9750
# Epoch 54/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 2.7094e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9850
# Epoch 55/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.1761 - val_accuracy: 0.9592
# Epoch 56/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0910 - val_accuracy: 0.9700
# Epoch 57/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.2327 - val_accuracy: 0.9475
# Epoch 58/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 3.5457e-04 - accuracy: 1.0000 - val_loss: 0.2534 - val_accuracy: 0.9517
# Epoch 59/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 3.7982e-04 - accuracy: 0.9999 - val_loss: 0.2307 - val_accuracy: 0.9575
# Epoch 60/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 1.5793e-04 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9583
# Epoch 61/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 4.2365e-04 - accuracy: 0.9999 - val_loss: 0.1844 - val_accuracy: 0.9625
# Epoch 62/100
# 15184/15184 [==============================] - 3s 191us/sample - loss: 2.7504e-04 - accuracy: 0.9999 - val_loss: 0.1572 - val_accuracy: 0.9633
# Epoch 63/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.3767 - val_accuracy: 0.9183
# Epoch 64/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1457 - val_accuracy: 0.9600
# Epoch 65/100
# 15184/15184 [==============================] - 3s 192us/sample - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1061 - val_accuracy: 0.9667
# Epoch 66/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 1.7275e-04 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9692
# Epoch 67/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 1.0634e-04 - accuracy: 1.0000 - val_loss: 0.1023 - val_accuracy: 0.9642
# Epoch 68/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.2184 - val_accuracy: 0.9425
# Epoch 69/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.1421 - val_accuracy: 0.9675
# Epoch 70/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 4.9227e-04 - accuracy: 0.9999 - val_loss: 0.1341 - val_accuracy: 0.9683
# Epoch 71/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 4.0523e-04 - accuracy: 0.9999 - val_loss: 0.1019 - val_accuracy: 0.9717
# Epoch 72/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 6.4698e-05 - accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 0.9767
# Epoch 73/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 2.1161e-04 - accuracy: 0.9999 - val_loss: 0.1300 - val_accuracy: 0.9633
# Epoch 74/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0881 - val_accuracy: 0.9667
# Epoch 75/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 7.1413e-04 - accuracy: 0.9998 - val_loss: 0.1826 - val_accuracy: 0.9575
# Epoch 76/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 2.2532e-04 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9683
# Epoch 77/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 1.1802e-04 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9692
# Epoch 78/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 7.2535e-04 - accuracy: 0.9998 - val_loss: 0.1270 - val_accuracy: 0.9675
# Epoch 79/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 3.3936e-04 - accuracy: 0.9999 - val_loss: 0.1684 - val_accuracy: 0.9533
# Epoch 80/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 8.1190e-04 - accuracy: 0.9997 - val_loss: 0.0660 - val_accuracy: 0.9783
# Epoch 81/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 9.3215e-04 - accuracy: 0.9998 - val_loss: 0.1220 - val_accuracy: 0.9592
# Epoch 82/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.2360 - val_accuracy: 0.9558
# Epoch 83/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1052 - val_accuracy: 0.9708
# Epoch 84/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1092 - val_accuracy: 0.9683
# Epoch 85/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 4.1340e-04 - accuracy: 0.9999 - val_loss: 0.0467 - val_accuracy: 0.9858
# Epoch 86/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 3.8289e-04 - accuracy: 0.9999 - val_loss: 0.0946 - val_accuracy: 0.9750
# Epoch 87/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 6.1480e-04 - accuracy: 0.9997 - val_loss: 0.0419 - val_accuracy: 0.9842
# Epoch 88/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 1.0304e-04 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 0.9825
# Epoch 89/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0333 - val_accuracy: 0.9917
# Epoch 90/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 5.5869e-04 - accuracy: 0.9999 - val_loss: 0.0464 - val_accuracy: 0.9875
# Epoch 91/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 1.1086e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9858
# Epoch 92/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0603 - val_accuracy: 0.9783
# Epoch 93/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1496 - val_accuracy: 0.9692
# Epoch 94/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0300 - val_accuracy: 0.9908
# Epoch 95/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.1257 - val_accuracy: 0.9700
# Epoch 96/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 7.4400e-04 - accuracy: 0.9998 - val_loss: 0.0963 - val_accuracy: 0.9642
# Epoch 97/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 3.5276e-04 - accuracy: 0.9999 - val_loss: 0.3896 - val_accuracy: 0.9125
# Epoch 98/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 2.9665e-04 - accuracy: 0.9999 - val_loss: 0.0302 - val_accuracy: 0.9883
# Epoch 99/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 1.2341e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9842
# Epoch 100/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 1.1359e-04 - accuracy: 0.9999 - val_loss: 0.0523 - val_accuracy: 0.9792
# 1200/1200 - 0s - loss: 0.0523 - accuracy: 0.9792
# test_loss: 0.052272065364757765
# test_accuracy: 0.9791666865348816
# 모델을 저장하였습니다. C:/Users/kwansu/Desktop/AIFFEL_LMS/E01_0.979167_0.052272'.h5'
# Train on 15184 samples, validate on 1200 samples
# Epoch 1/100
# 15184/15184 [==============================] - 3s 226us/sample - loss: 0.2675 - accuracy: 0.9011 - val_loss: 0.2812 - val_accuracy: 0.8800
# Epoch 2/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0706 - accuracy: 0.9761 - val_loss: 0.6468 - val_accuracy: 0.7600
# Epoch 3/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0323 - accuracy: 0.9907 - val_loss: 0.2252 - val_accuracy: 0.9233
# Epoch 4/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0249 - accuracy: 0.9922 - val_loss: 0.1789 - val_accuracy: 0.9192
# Epoch 5/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0188 - accuracy: 0.9938 - val_loss: 0.1547 - val_accuracy: 0.9433
# Epoch 6/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.2187 - val_accuracy: 0.9108
# Epoch 7/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.3018 - val_accuracy: 0.9017
# Epoch 8/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 0.0202 - accuracy: 0.9936 - val_loss: 0.2211 - val_accuracy: 0.9333
# Epoch 9/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.3743 - val_accuracy: 0.8975
# Epoch 10/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.1473 - val_accuracy: 0.9458
# Epoch 11/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.2324 - val_accuracy: 0.9283
# Epoch 12/100
# 15184/15184 [==============================] - 3s 194us/sample - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.1909 - val_accuracy: 0.9383
# Epoch 13/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.2493 - val_accuracy: 0.9217
# Epoch 14/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.1390 - val_accuracy: 0.9533
# Epoch 15/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1401 - val_accuracy: 0.9575
# Epoch 16/100
# 15184/15184 [==============================] - 3s 196us/sample - loss: 0.0177 - accuracy: 0.9945 - val_loss: 0.1965 - val_accuracy: 0.9392
# Epoch 17/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.1086 - val_accuracy: 0.9558
# Epoch 18/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0810 - val_accuracy: 0.9758
# Epoch 19/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.2529 - val_accuracy: 0.9367
# Epoch 20/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.1603 - val_accuracy: 0.9533
# Epoch 21/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.1311 - val_accuracy: 0.9458
# Epoch 22/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 0.0109 - accuracy: 0.9968 - val_loss: 0.2448 - val_accuracy: 0.9242
# Epoch 23/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1128 - val_accuracy: 0.9642
# Epoch 24/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0609 - val_accuracy: 0.9758
# Epoch 25/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.2415 - val_accuracy: 0.9367
# Epoch 26/100
# 15184/15184 [==============================] - 3s 191us/sample - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.1353 - val_accuracy: 0.9508
# Epoch 27/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1962 - val_accuracy: 0.9392
# Epoch 28/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 5.5043e-04 - accuracy: 0.9999 - val_loss: 0.1031 - val_accuracy: 0.9642
# Epoch 29/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1011 - val_accuracy: 0.9708
# Epoch 30/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 3.7622e-04 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9692
# Epoch 31/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0160 - accuracy: 0.9952 - val_loss: 0.2369 - val_accuracy: 0.9233
# Epoch 32/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.2467 - val_accuracy: 0.9242
# Epoch 33/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0763 - val_accuracy: 0.9750
# Epoch 34/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1457 - val_accuracy: 0.9592
# Epoch 35/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1014 - val_accuracy: 0.9725
# Epoch 36/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.1511 - val_accuracy: 0.9608
# Epoch 37/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.0826 - val_accuracy: 0.9775
# Epoch 38/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1088 - val_accuracy: 0.9675
# Epoch 39/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0706 - val_accuracy: 0.9750
# Epoch 40/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0792 - val_accuracy: 0.9733
# Epoch 41/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0778 - val_accuracy: 0.9775
# Epoch 42/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 4.0273e-04 - accuracy: 0.9999 - val_loss: 0.0705 - val_accuracy: 0.9783
# Epoch 43/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.1412 - val_accuracy: 0.9650
# Epoch 44/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.1371 - val_accuracy: 0.9533
# Epoch 45/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.3440 - val_accuracy: 0.9100
# Epoch 46/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0797 - val_accuracy: 0.9783
# Epoch 47/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1423 - val_accuracy: 0.9575
# Epoch 48/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.2295 - val_accuracy: 0.9417
# Epoch 49/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.1473 - val_accuracy: 0.9650
# Epoch 50/100
# 15184/15184 [==============================] - 3s 199us/sample - loss: 8.6205e-04 - accuracy: 0.9998 - val_loss: 0.1367 - val_accuracy: 0.9583
# Epoch 51/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 3.6778e-04 - accuracy: 0.9999 - val_loss: 0.1858 - val_accuracy: 0.9458
# Epoch 52/100
# 15184/15184 [==============================] - 3s 183us/sample - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1727 - val_accuracy: 0.9575
# Epoch 53/100
# 15184/15184 [==============================] - 3s 194us/sample - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.1294 - val_accuracy: 0.9675
# Epoch 54/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0447 - val_accuracy: 0.9883
# Epoch 55/100
# 15184/15184 [==============================] - 3s 183us/sample - loss: 5.0073e-04 - accuracy: 0.9999 - val_loss: 0.0652 - val_accuracy: 0.9775
# Epoch 56/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 1.3860e-04 - accuracy: 1.0000 - val_loss: 0.0648 - val_accuracy: 0.9800
# Epoch 57/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 1.0491e-04 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9808
# Epoch 58/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.1215 - val_accuracy: 0.9625
# Epoch 59/100
# 15184/15184 [==============================] - 3s 192us/sample - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0413 - val_accuracy: 0.9875
# Epoch 60/100
# 15184/15184 [==============================] - 3s 195us/sample - loss: 6.7279e-04 - accuracy: 0.9999 - val_loss: 0.0979 - val_accuracy: 0.9692
# Epoch 61/100
# 15184/15184 [==============================] - 3s 189us/sample - loss: 1.9118e-04 - accuracy: 1.0000 - val_loss: 0.0821 - val_accuracy: 0.9858
# Epoch 62/100
# 15184/15184 [==============================] - 3s 201us/sample - loss: 7.1197e-04 - accuracy: 0.9999 - val_loss: 0.0643 - val_accuracy: 0.9850
# Epoch 63/100
# 15184/15184 [==============================] - 3s 207us/sample - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.2826 - val_accuracy: 0.9442
# Epoch 64/100
# 15184/15184 [==============================] - 3s 201us/sample - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.0619 - val_accuracy: 0.9817
# Epoch 65/100
# 15184/15184 [==============================] - 3s 203us/sample - loss: 7.0444e-04 - accuracy: 0.9999 - val_loss: 0.1066 - val_accuracy: 0.9700
# Epoch 66/100
# 15184/15184 [==============================] - 3s 196us/sample - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0980 - val_accuracy: 0.9750
# Epoch 67/100
# 15184/15184 [==============================] - 3s 194us/sample - loss: 8.3278e-04 - accuracy: 0.9998 - val_loss: 0.1145 - val_accuracy: 0.9708
# Epoch 68/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 2.5200e-04 - accuracy: 0.9999 - val_loss: 0.0965 - val_accuracy: 0.9758
# Epoch 69/100
# 15184/15184 [==============================] - 3s 196us/sample - loss: 6.5499e-05 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9767
# Epoch 70/100
# 15184/15184 [==============================] - 3s 194us/sample - loss: 8.9250e-05 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 0.9775
# Epoch 71/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 3.2327e-05 - accuracy: 1.0000 - val_loss: 0.0771 - val_accuracy: 0.9800
# Epoch 72/100
# 15184/15184 [==============================] - 3s 199us/sample - loss: 4.8515e-05 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9742
# Epoch 73/100
# 15184/15184 [==============================] - 3s 195us/sample - loss: 3.4435e-05 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9775
# Epoch 74/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 2.5692e-05 - accuracy: 1.0000 - val_loss: 0.0790 - val_accuracy: 0.9750
# Epoch 75/100
# 15184/15184 [==============================] - 3s 198us/sample - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0886 - val_accuracy: 0.9767
# Epoch 76/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1528 - val_accuracy: 0.9625
# Epoch 77/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 4.5996e-04 - accuracy: 0.9999 - val_loss: 0.1131 - val_accuracy: 0.9683
# Epoch 78/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 4.3423e-04 - accuracy: 0.9999 - val_loss: 0.1091 - val_accuracy: 0.9717
# Epoch 79/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 4.0559e-04 - accuracy: 0.9998 - val_loss: 0.0428 - val_accuracy: 0.9875
# Epoch 80/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 9.7499e-05 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 0.9858
# Epoch 81/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 8.0405e-05 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9750
# Epoch 82/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0656 - val_accuracy: 0.9800
# Epoch 83/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 1.3982e-04 - accuracy: 1.0000 - val_loss: 0.0802 - val_accuracy: 0.9800
# Epoch 84/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.1799 - val_accuracy: 0.9558
# Epoch 85/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.0715 - val_accuracy: 0.9783
# Epoch 86/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 2.3361e-04 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9817
# Epoch 87/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 8.9609e-04 - accuracy: 0.9997 - val_loss: 0.0846 - val_accuracy: 0.9758
# Epoch 88/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.2024 - val_accuracy: 0.9567
# Epoch 89/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 4.8129e-04 - accuracy: 0.9999 - val_loss: 0.0767 - val_accuracy: 0.9775
# Epoch 90/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 4.6184e-04 - accuracy: 0.9999 - val_loss: 0.0693 - val_accuracy: 0.9792
# Epoch 91/100
# 15184/15184 [==============================] - 3s 195us/sample - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1283 - val_accuracy: 0.9700
# Epoch 92/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.1104 - val_accuracy: 0.9683
# Epoch 93/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 9.2963e-04 - accuracy: 0.9997 - val_loss: 0.1416 - val_accuracy: 0.9633
# Epoch 94/100
# 15184/15184 [==============================] - 3s 194us/sample - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0898 - val_accuracy: 0.9733
# Epoch 95/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 1.3208e-04 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9708
# Epoch 96/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 4.4441e-05 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 0.9725
# Epoch 97/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 5.4637e-05 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 0.9783
# Epoch 98/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 3.0857e-05 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9817
# Epoch 99/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 4.4573e-05 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9808
# Epoch 100/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 4.1113e-05 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9808
# 1200/1200 - 0s - loss: 0.0669 - accuracy: 0.9808
# test_loss: 0.0669127126051013
# test_accuracy: 0.9808333516120911
# 모델을 저장하였습니다. C:/Users/kwansu/Desktop/AIFFEL_LMS/E01_0.980833_0.066913'.h5'
# Train on 15184 samples, validate on 1200 samples
# Epoch 1/100
# 15184/15184 [==============================] - 4s 240us/sample - loss: 0.2543 - accuracy: 0.9036 - val_loss: 0.2861 - val_accuracy: 0.8908
# Epoch 2/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 0.0732 - accuracy: 0.9756 - val_loss: 0.1936 - val_accuracy: 0.9217
# Epoch 3/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0351 - accuracy: 0.9888 - val_loss: 0.1804 - val_accuracy: 0.9342
# Epoch 4/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 0.0229 - accuracy: 0.9928 - val_loss: 0.3099 - val_accuracy: 0.8775
# Epoch 5/100
# 15184/15184 [==============================] - 3s 191us/sample - loss: 0.0258 - accuracy: 0.9922 - val_loss: 0.1612 - val_accuracy: 0.9317
# Epoch 6/100
# 15184/15184 [==============================] - 3s 191us/sample - loss: 0.0228 - accuracy: 0.9928 - val_loss: 0.2292 - val_accuracy: 0.9208
# Epoch 7/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0089 - accuracy: 0.9978 - val_loss: 0.2511 - val_accuracy: 0.9142
# Epoch 8/100
# 15184/15184 [==============================] - 3s 199us/sample - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.2877 - val_accuracy: 0.8942
# Epoch 9/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 0.0140 - accuracy: 0.9951 - val_loss: 0.4682 - val_accuracy: 0.8750
# Epoch 10/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 0.0095 - accuracy: 0.9977 - val_loss: 0.0907 - val_accuracy: 0.9700
# Epoch 11/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.1725 - val_accuracy: 0.9608
# Epoch 12/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.1450 - val_accuracy: 0.9550
# Epoch 13/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0069 - accuracy: 0.9981 - val_loss: 0.0708 - val_accuracy: 0.9775
# Epoch 14/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0100 - accuracy: 0.9967 - val_loss: 0.1945 - val_accuracy: 0.9375
# Epoch 15/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.1160 - val_accuracy: 0.9550
# Epoch 16/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.3249 - val_accuracy: 0.9150
# Epoch 17/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.1381 - val_accuracy: 0.9617
# Epoch 18/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0894 - val_accuracy: 0.9717
# Epoch 19/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 0.0064 - accuracy: 0.9978 - val_loss: 1.5437 - val_accuracy: 0.7292
# Epoch 20/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.0583 - val_accuracy: 0.9808
# Epoch 21/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0051 - accuracy: 0.9980 - val_loss: 0.1289 - val_accuracy: 0.9542
# Epoch 22/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0540 - val_accuracy: 0.9833
# Epoch 23/100
# 15184/15184 [==============================] - 3s 186us/sample - loss: 5.5944e-04 - accuracy: 0.9999 - val_loss: 0.0645 - val_accuracy: 0.9783
# Epoch 24/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.1100 - val_accuracy: 0.9617
# Epoch 25/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.2241 - val_accuracy: 0.9300
# Epoch 26/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.1530 - val_accuracy: 0.9492
# Epoch 27/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 7.0644e-04 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9800
# Epoch 28/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.1629 - val_accuracy: 0.9492
# Epoch 29/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.0430 - val_accuracy: 0.9842
# Epoch 30/100
# 15184/15184 [==============================] - 3s 191us/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1134 - val_accuracy: 0.9683
# Epoch 31/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.1342 - val_accuracy: 0.9658
# Epoch 32/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0541 - val_accuracy: 0.9775
# Epoch 33/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.1755 - val_accuracy: 0.9483
# Epoch 34/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0732 - val_accuracy: 0.9725
# Epoch 35/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0711 - val_accuracy: 0.9733
# Epoch 36/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 3.3037e-04 - accuracy: 1.0000 - val_loss: 0.0573 - val_accuracy: 0.9792
# Epoch 37/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 1.9709e-04 - accuracy: 1.0000 - val_loss: 0.0530 - val_accuracy: 0.9808
# Epoch 38/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 3.6396e-04 - accuracy: 0.9999 - val_loss: 0.0520 - val_accuracy: 0.9800
# Epoch 39/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 1.5428e-04 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9783
# Epoch 40/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 9.8605e-05 - accuracy: 1.0000 - val_loss: 0.0554 - val_accuracy: 0.9817
# Epoch 41/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 6.4876e-05 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9792
# Epoch 42/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 7.9102e-05 - accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 0.9825
# Epoch 43/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.3791 - val_accuracy: 0.8983
# Epoch 44/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.1597 - val_accuracy: 0.9483
# Epoch 45/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.3838 - val_accuracy: 0.8892
# Epoch 46/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 6.4755e-04 - accuracy: 0.9999 - val_loss: 0.2802 - val_accuracy: 0.9292
# Epoch 47/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.1879 - val_accuracy: 0.9517
# Epoch 48/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.1459 - val_accuracy: 0.9542
# Epoch 49/100
# 15184/15184 [==============================] - 3s 183us/sample - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1481 - val_accuracy: 0.9442
# Epoch 50/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 2.3842e-04 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9458
# Epoch 51/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 3.8229e-04 - accuracy: 0.9999 - val_loss: 0.1784 - val_accuracy: 0.9383
# Epoch 52/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.4810 - val_accuracy: 0.8967
# Epoch 53/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1884 - val_accuracy: 0.9475
# Epoch 54/100
# 15184/15184 [==============================] - 3s 170us/sample - loss: 1.4235e-04 - accuracy: 1.0000 - val_loss: 0.2750 - val_accuracy: 0.9308
# Epoch 55/100
# 15184/15184 [==============================] - 3s 171us/sample - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.1184 - val_accuracy: 0.9600
# Epoch 56/100
# 15184/15184 [==============================] - 3s 198us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0948 - val_accuracy: 0.9650
# Epoch 57/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 3.2625e-04 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9550
# Epoch 58/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 1.1971e-04 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9683
# Epoch 59/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.1331 - val_accuracy: 0.9608
# Epoch 60/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1689 - val_accuracy: 0.9567
# Epoch 61/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 7.8357e-04 - accuracy: 0.9998 - val_loss: 0.2091 - val_accuracy: 0.9450
# Epoch 62/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 1.2418e-04 - accuracy: 1.0000 - val_loss: 0.1085 - val_accuracy: 0.9617
# Epoch 63/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 1.1366e-04 - accuracy: 1.0000 - val_loss: 0.1749 - val_accuracy: 0.9525
# Epoch 64/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 5.2012e-05 - accuracy: 1.0000 - val_loss: 0.1604 - val_accuracy: 0.9542
# Epoch 65/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 4.6196e-05 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9567
# Epoch 66/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 2.5983e-05 - accuracy: 1.0000 - val_loss: 0.1605 - val_accuracy: 0.9567
# Epoch 67/100
# 15184/15184 [==============================] - 3s 197us/sample - loss: 3.1312e-05 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9650
# Epoch 68/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 2.2097e-04 - accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 0.9925
# Epoch 69/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.2745 - val_accuracy: 0.9300
# Epoch 70/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 9.7479e-04 - accuracy: 0.9996 - val_loss: 0.2563 - val_accuracy: 0.9267
# Epoch 71/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 2.1546e-04 - accuracy: 1.0000 - val_loss: 0.2834 - val_accuracy: 0.9300
# Epoch 72/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.6400 - val_accuracy: 0.8475
# Epoch 73/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 3.7110e-04 - accuracy: 0.9999 - val_loss: 0.2580 - val_accuracy: 0.9308
# Epoch 74/100
# 15184/15184 [==============================] - 3s 185us/sample - loss: 1.6239e-04 - accuracy: 0.9999 - val_loss: 0.2898 - val_accuracy: 0.9250
# Epoch 75/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0910 - val_accuracy: 0.9750
# Epoch 76/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 2.3473e-04 - accuracy: 1.0000 - val_loss: 0.0989 - val_accuracy: 0.9692
# Epoch 77/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 1.0188e-04 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9658
# Epoch 78/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 6.7026e-05 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9550
# Epoch 79/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 2.3725e-05 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9650
# Epoch 80/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 4.4022e-05 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9567
# Epoch 81/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 8.5200e-05 - accuracy: 1.0000 - val_loss: 0.3249 - val_accuracy: 0.9242
# Epoch 82/100
# 15184/15184 [==============================] - 3s 203us/sample - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.1808 - val_accuracy: 0.9417
# Epoch 83/100
# 15184/15184 [==============================] - 3s 204us/sample - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0999 - val_accuracy: 0.9725
# Epoch 84/100
# 15184/15184 [==============================] - 3s 206us/sample - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.2110 - val_accuracy: 0.9433
# Epoch 85/100
# 15184/15184 [==============================] - 3s 203us/sample - loss: 6.6313e-04 - accuracy: 0.9998 - val_loss: 0.6176 - val_accuracy: 0.8817
# Epoch 86/100
# 15184/15184 [==============================] - 3s 202us/sample - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1149 - val_accuracy: 0.9625
# Epoch 87/100
# 15184/15184 [==============================] - 3s 202us/sample - loss: 1.4323e-04 - accuracy: 1.0000 - val_loss: 0.1827 - val_accuracy: 0.9433
# Epoch 88/100
# 15184/15184 [==============================] - 3s 214us/sample - loss: 1.1326e-04 - accuracy: 1.0000 - val_loss: 0.3456 - val_accuracy: 0.9083
# Epoch 89/100
# 15184/15184 [==============================] - 3s 203us/sample - loss: 7.0951e-05 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9692
# Epoch 90/100
# 15184/15184 [==============================] - 3s 200us/sample - loss: 4.1890e-05 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9783
# Epoch 91/100
# 15184/15184 [==============================] - 3s 197us/sample - loss: 7.7059e-05 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9542
# Epoch 92/100
# 15184/15184 [==============================] - 3s 207us/sample - loss: 5.6450e-05 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 0.9842
# Epoch 93/100
# 15184/15184 [==============================] - 3s 199us/sample - loss: 5.6791e-05 - accuracy: 1.0000 - val_loss: 0.0501 - val_accuracy: 0.9850
# Epoch 94/100
# 15184/15184 [==============================] - 3s 196us/sample - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.4326 - val_accuracy: 0.9167
# Epoch 95/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0854 - val_accuracy: 0.9733
# Epoch 96/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 8.0191e-04 - accuracy: 0.9997 - val_loss: 0.0894 - val_accuracy: 0.9775
# Epoch 97/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 1.6895e-04 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9633
# Epoch 98/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 5.5929e-04 - accuracy: 0.9999 - val_loss: 0.0505 - val_accuracy: 0.9825
# Epoch 99/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.2706 - val_accuracy: 0.9383
# Epoch 100/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 8.3094e-04 - accuracy: 0.9997 - val_loss: 0.1891 - val_accuracy: 0.9533
# 1200/1200 - 0s - loss: 0.1891 - accuracy: 0.9533
# test_loss: 0.18907416213865663
# test_accuracy: 0.95333331823349
# 모델을 저장하였습니다. C:/Users/kwansu/Desktop/AIFFEL_LMS/E01_0.953333_0.189074'.h5'
# Train on 15184 samples, validate on 1200 samples
# Epoch 1/100
# 15184/15184 [==============================] - 4s 242us/sample - loss: 0.2411 - accuracy: 0.9067 - val_loss: 0.6166 - val_accuracy: 0.7858
# Epoch 2/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0606 - accuracy: 0.9796 - val_loss: 0.6900 - val_accuracy: 0.7892
# Epoch 3/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 0.0339 - accuracy: 0.9898 - val_loss: 0.2367 - val_accuracy: 0.9317
# Epoch 4/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0168 - accuracy: 0.9953 - val_loss: 0.2543 - val_accuracy: 0.9033
# Epoch 5/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0236 - accuracy: 0.9919 - val_loss: 0.1973 - val_accuracy: 0.9375
# Epoch 6/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.7402 - val_accuracy: 0.8242
# Epoch 7/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0095 - accuracy: 0.9974 - val_loss: 0.5605 - val_accuracy: 0.8667
# Epoch 8/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0215 - accuracy: 0.9933 - val_loss: 0.3649 - val_accuracy: 0.9050
# Epoch 9/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.1539 - val_accuracy: 0.9475
# Epoch 10/100
# 15184/15184 [==============================] - 3s 173us/sample - loss: 0.0150 - accuracy: 0.9960 - val_loss: 0.3356 - val_accuracy: 0.9058
# Epoch 11/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.2036 - val_accuracy: 0.9242
# Epoch 12/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.2059 - val_accuracy: 0.9308
# Epoch 13/100
# 15184/15184 [==============================] - 3s 173us/sample - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1894 - val_accuracy: 0.9475
# Epoch 14/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 0.0204 - accuracy: 0.9937 - val_loss: 0.0746 - val_accuracy: 0.9758
# Epoch 15/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0886 - val_accuracy: 0.9650
# Epoch 16/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0093 - accuracy: 0.9966 - val_loss: 0.0992 - val_accuracy: 0.9667
# Epoch 17/100
# 15184/15184 [==============================] - 3s 173us/sample - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0658 - val_accuracy: 0.9725
# Epoch 18/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.5062 - val_accuracy: 0.8792
# Epoch 19/100
# 15184/15184 [==============================] - 3s 192us/sample - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.1115 - val_accuracy: 0.9583
# Epoch 20/100
# 15184/15184 [==============================] - 3s 197us/sample - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0603 - val_accuracy: 0.9800
# Epoch 21/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0767 - val_accuracy: 0.9700
# Epoch 22/100
# 15184/15184 [==============================] - 3s 191us/sample - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0384 - val_accuracy: 0.9808
# Epoch 23/100
# 15184/15184 [==============================] - 3s 195us/sample - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.0373 - val_accuracy: 0.9867
# Epoch 24/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.1203 - val_accuracy: 0.9617
# Epoch 25/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0525 - val_accuracy: 0.9750
# Epoch 26/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0761 - val_accuracy: 0.9700
# Epoch 27/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 8.5270e-04 - accuracy: 0.9999 - val_loss: 0.1017 - val_accuracy: 0.9667
# Epoch 28/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.1153 - val_accuracy: 0.9658
# Epoch 29/100
# 15184/15184 [==============================] - 3s 203us/sample - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1030 - val_accuracy: 0.9642
# Epoch 30/100
# 15184/15184 [==============================] - 3s 187us/sample - loss: 2.6033e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9658
# Epoch 31/100
# 15184/15184 [==============================] - 3s 183us/sample - loss: 3.3921e-04 - accuracy: 0.9999 - val_loss: 0.0792 - val_accuracy: 0.9725
# Epoch 32/100
# 15184/15184 [==============================] - 3s 189us/sample - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.0673 - val_accuracy: 0.9758
# Epoch 33/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 0.0036 - accuracy: 0.9984 - val_loss: 0.0419 - val_accuracy: 0.9875
# Epoch 34/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.1098 - val_accuracy: 0.9667
# Epoch 35/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.3784 - val_accuracy: 0.9258
# Epoch 36/100
# 15184/15184 [==============================] - 3s 184us/sample - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.1455 - val_accuracy: 0.9642
# Epoch 37/100
# 15184/15184 [==============================] - 3s 200us/sample - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1324 - val_accuracy: 0.9633
# Epoch 38/100
# 15184/15184 [==============================] - 3s 199us/sample - loss: 1.9007e-04 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9600
# Epoch 39/100
# 15184/15184 [==============================] - 3s 208us/sample - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.1338 - val_accuracy: 0.9617
# Epoch 40/100
# 15184/15184 [==============================] - 3s 202us/sample - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.1175 - val_accuracy: 0.9675
# Epoch 41/100
# 15184/15184 [==============================] - 3s 205us/sample - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0856 - val_accuracy: 0.9808
# Epoch 42/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 3.3998e-04 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9758
# Epoch 43/100
# 15184/15184 [==============================] - 3s 203us/sample - loss: 5.5976e-04 - accuracy: 0.9999 - val_loss: 0.0729 - val_accuracy: 0.9808
# Epoch 44/100
# 15184/15184 [==============================] - 3s 199us/sample - loss: 1.6954e-04 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9783
# Epoch 45/100
# 15184/15184 [==============================] - 3s 199us/sample - loss: 5.7639e-05 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9792
# Epoch 46/100
# 15184/15184 [==============================] - 3s 201us/sample - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.3135 - val_accuracy: 0.9283
# Epoch 47/100
# 15184/15184 [==============================] - 3s 201us/sample - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.1646 - val_accuracy: 0.9600
# Epoch 48/100
# 15184/15184 [==============================] - 3s 212us/sample - loss: 9.4945e-04 - accuracy: 0.9998 - val_loss: 0.1867 - val_accuracy: 0.9508
# Epoch 49/100
# 15184/15184 [==============================] - 3s 200us/sample - loss: 4.6566e-04 - accuracy: 0.9999 - val_loss: 0.1059 - val_accuracy: 0.9717
# Epoch 50/100
# 15184/15184 [==============================] - 3s 203us/sample - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0577 - val_accuracy: 0.9775
# Epoch 51/100
# 15184/15184 [==============================] - 3s 213us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0734 - val_accuracy: 0.9775
# Epoch 52/100
# 15184/15184 [==============================] - 3s 194us/sample - loss: 3.3630e-04 - accuracy: 0.9999 - val_loss: 0.0771 - val_accuracy: 0.9792
# Epoch 53/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 1.7942e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9633
# Epoch 54/100
# 15184/15184 [==============================] - 3s 191us/sample - loss: 7.6963e-04 - accuracy: 0.9998 - val_loss: 0.2455 - val_accuracy: 0.9433
# Epoch 55/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.1753 - val_accuracy: 0.9558
# Epoch 56/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 7.3234e-04 - accuracy: 0.9997 - val_loss: 0.1149 - val_accuracy: 0.9683
# Epoch 57/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 2.9700e-04 - accuracy: 0.9999 - val_loss: 0.1464 - val_accuracy: 0.9575
# Epoch 58/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 1.1400e-04 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9733
# Epoch 59/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 7.6596e-05 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9725
# Epoch 60/100
# 15184/15184 [==============================] - 3s 182us/sample - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.1429 - val_accuracy: 0.9575
# Epoch 61/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.1794 - val_accuracy: 0.9575
# Epoch 62/100
# 15184/15184 [==============================] - 3s 174us/sample - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1119 - val_accuracy: 0.9650
# Epoch 63/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 1.6325e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9675
# Epoch 64/100
# 15184/15184 [==============================] - 3s 195us/sample - loss: 2.9772e-04 - accuracy: 0.9999 - val_loss: 0.1687 - val_accuracy: 0.9592
# Epoch 65/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 0.0013 - accuracy: 0.9993 - val_loss: 0.2943 - val_accuracy: 0.9333
# Epoch 66/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1339 - val_accuracy: 0.9600
# Epoch 67/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1202 - val_accuracy: 0.9583
# Epoch 68/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0644 - val_accuracy: 0.9842
# Epoch 69/100
# 15184/15184 [==============================] - 3s 175us/sample - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0970 - val_accuracy: 0.9783
# Epoch 70/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.0732 - val_accuracy: 0.9817
# Epoch 71/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0505 - val_accuracy: 0.9850
# Epoch 72/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 4.6671e-04 - accuracy: 0.9999 - val_loss: 0.1024 - val_accuracy: 0.9742
# Epoch 73/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 6.3705e-04 - accuracy: 0.9998 - val_loss: 0.0709 - val_accuracy: 0.9758
# Epoch 74/100
# 15184/15184 [==============================] - 3s 181us/sample - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0501 - val_accuracy: 0.9867
# Epoch 75/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 4.0165e-04 - accuracy: 0.9999 - val_loss: 0.1023 - val_accuracy: 0.9808
# Epoch 76/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 1.2963e-04 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9842
# Epoch 77/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 6.5692e-05 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9825
# Epoch 78/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0803 - val_accuracy: 0.9717
# Epoch 79/100
# 15184/15184 [==============================] - 3s 192us/sample - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0528 - val_accuracy: 0.9792
# Epoch 80/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 7.1321e-04 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9758
# Epoch 81/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 4.1255e-04 - accuracy: 0.9999 - val_loss: 0.0984 - val_accuracy: 0.9733
# Epoch 82/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 8.1809e-05 - accuracy: 1.0000 - val_loss: 0.1020 - val_accuracy: 0.9725
# Epoch 83/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 6.4269e-05 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 0.9825
# Epoch 84/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 6.2796e-04 - accuracy: 0.9998 - val_loss: 0.1258 - val_accuracy: 0.9700
# Epoch 85/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.1076 - val_accuracy: 0.9692
# Epoch 86/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 2.6094e-04 - accuracy: 0.9999 - val_loss: 0.1849 - val_accuracy: 0.9692
# Epoch 87/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 4.8964e-04 - accuracy: 0.9999 - val_loss: 0.0919 - val_accuracy: 0.9700
# Epoch 88/100
# 15184/15184 [==============================] - 3s 179us/sample - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.1266 - val_accuracy: 0.9742
# Epoch 89/100
# 15184/15184 [==============================] - 3s 180us/sample - loss: 8.4061e-04 - accuracy: 0.9999 - val_loss: 0.1629 - val_accuracy: 0.9692
# Epoch 90/100
# 15184/15184 [==============================] - 3s 177us/sample - loss: 9.0563e-05 - accuracy: 1.0000 - val_loss: 0.1814 - val_accuracy: 0.9658
# Epoch 91/100
# 15184/15184 [==============================] - 3s 176us/sample - loss: 7.3797e-05 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9667
# Epoch 92/100
# 15184/15184 [==============================] - 3s 178us/sample - loss: 2.4371e-04 - accuracy: 0.9999 - val_loss: 0.1919 - val_accuracy: 0.9608
# Epoch 93/100
# 15184/15184 [==============================] - 3s 188us/sample - loss: 8.8860e-05 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9792
# Epoch 94/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 6.0583e-05 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9783
# Epoch 95/100
# 15184/15184 [==============================] - 3s 190us/sample - loss: 3.3339e-05 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9783
# Epoch 96/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.1342 - val_accuracy: 0.9700
# Epoch 97/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 4.8916e-04 - accuracy: 0.9999 - val_loss: 0.1390 - val_accuracy: 0.9767
# Epoch 98/100
# 15184/15184 [==============================] - 3s 195us/sample - loss: 1.7611e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9708
# Epoch 99/100
# 15184/15184 [==============================] - 3s 193us/sample - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.2660 - val_accuracy: 0.9458
# Epoch 100/100
# 15184/15184 [==============================] - 3s 194us/sample - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.1013 - val_accuracy: 0.9708
# 1200/1200 - 0s - loss: 0.1013 - accuracy: 0.9708
# test_loss: 0.10132708312138643
# test_accuracy: 0.9708333611488342
# 모델을 저장하였습니다. C:/Users/kwansu/Desktop/AIFFEL_LMS/E01_0.970833_0.101327'.h5'

# %% [markdown]
# 앙상블의 효과를 보기 위해 tensorflow.keras.Model의 predict함수 대신 직접 accuracy를 구하였다.

# %%
save_path = 'C:/Users/kwansu/Desktop/AIFFEL_LMS'

loaded_models = [tf.keras.models.load_model(file) for file in glob.iglob(save_path+'/*.h5')]
print(f"{len(loaded_models)} 개의 모델을 불러왔습니다.")
# Out:
# 4 개의 모델을 불러왔습니다.

# %%
predictions = [model.predict(x_test_normalized) for model in loaded_models]
predictions = np.sum(predictions, axis=0) / ensembles

ensemble_correct_prediction = np.equal(np.argmax(predictions, 1), y_test)
print(f"Ensemble accuracy: {np.mean(ensemble_correct_prediction)}")
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 154
# Ensemble accuracy: 0.9941666666666666

# %% [markdown]
# 최종 결과는 0.9958이 나왔다.
# 여러번 실험 결과 0.989~0.998사이를 왔다갔다 하였다.
#
# 잘못 평가된 데이터를 모아보았다.

# %%
wrong_indices = np.where(ensemble_correct_prediction == 0)[0]
print(f"잘못 평가한 이미지 개수 : {len(wrong_indices)}")

for i in wrong_indices:
    plt.imshow(x_test[i])
    plt.show()
    print(f"확률평가 (가위:{predictions[i,0]:f}),(바위:{predictions[i,1]:f}),(보:{predictions[i,2]:f})")
# Out:
# 잘못 평가한 이미지 개수 : 7
# 확률평가 (가위:0.474578),(바위:0.000000),(보:0.525422)
# 확률평가 (가위:0.450930),(바위:0.000000),(보:0.549070)
# 확률평가 (가위:0.397672),(바위:0.122038),(보:0.480290)
# 확률평가 (가위:0.497233),(바위:0.486378),(보:0.016389)
# 확률평가 (가위:0.000087),(바위:0.462268),(보:0.537644)
# 확률평가 (가위:0.000000),(바위:0.458096),(보:0.541904)
# 확률평가 (가위:0.000000),(바위:0.317400),(보:0.682600)

# %% [markdown]
# 틀린 내용을 자세히 보면 가위와 보의 경우, 0.01퍼의 확률차이로 잘못 판단한 것으로 나온다.
# 그리고 주먹이 크게 나온 사진의 경우는 보와 바위가 비슷한 확률로 나온다.
#
# 특히 바위의 경우는 손등이 나온 경우 손가락이 안보여서 붙여진 보와 구분이 힘든 것으로 생각된다.
#
# 이 부분은 픽셀이 줄어들면서 구분하기 힘들어 진 부분도 있다고 예상된다.

# %% [markdown]
# ### 총평
#
# 가위, 바위, 보 이미지를 인식하는 모델을 만들어보았다.
# 초기의 스스로 찍은 300개(100 * 3) 이미지로 학습한 경우 같은 환경(스스로 찍은)에서는
# 테스트데이터를 전혀 학습에 영향을 주지 않아도 1.0이 나왔었다.
#
# 문제는 다른 환경(다른 사람이 찍은 이미지)에서는 정답률이 매우 떨어졌다.
# 당연히 스스로 찍은 하나의 환경에서 학습한 데이터이기 때문이다.
#
# 그래서 여러 사람들이 올린 이미지를 모아서 학습을 시키고, 또 다른 사람의 이미지로
# 테스트를 했지만, 여전히 성능이 좋지않았다.
#
# 전체적으로 학습데이터의 부족과 잘못된 학습 데이터가 있다는 문제가 생각되었다.
#
# 우선적으로 사람이 보기에도 애매한 이미지(잔상, 보를 옆면으로 일자로 편 경우등)를
# 제거하여, 확실히 구분 가능한 학습데이터들만 남겼고, 너무 배경이 화려해서 손에 이미지가
# 구분이 안가는 경우도 제외시켰다.
#
# 그 다음으로는 너무 단일 방향인 손 이미지들을 좌우반전과 회전을 통해 다양한 이미지를 얻었다.
# 거기에 환경마다 색이 다를 수 있고, 실제로 가위/바위/보의 경우 색이 중요하지 않다고 판단하여,
# 색을 반전시켜서 학습시켰다.
#
# 확실히 위의 이미지의 다양성을 늘리니깐 0.9이상으로 accuracy가 늘었다.
# 거기에 많은 epohc에서 테스트 정답률이 떨어지는 overfit을 막기 위해 batch normalization을 사용하였다.
# 추가적으로 마지막 애매하게 안오르는 accuracy를 올리기 위해 ensemble을 사용하여,
# 최종적으로 0.995 accuracy를 얻게되었다.
#
# 개인적으로 좀더 화질을 올리거나 다양한(대신 확실히 분류가능한) 데이터가 있으면,
# 좀 더 범용적인 인식기를 만들 수 있을 것 같다는 생각이 들었다.
